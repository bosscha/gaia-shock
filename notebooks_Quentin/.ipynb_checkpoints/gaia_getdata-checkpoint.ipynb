# %%
import sys, os
sys.path.append('C:\\Users\Quentin\\Documents\\ALMA_CHILI\\gaia-shock\\src')

## directory
rootdir = r'C:\Users\Quentin\Documents\ALMA_CHILI'
wdir    = r'%s\products'%(rootdir)
#notedir = r'%s\gaia-shock\notebooks_Quentin'%(rootdir)

os.chdir(wdir)  # to change the current directory

import gaia_utils_quentin as gu
# Out:
# Created TAP+ (v1.0.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443

# %%
name_list = ["M67", "NGC2516", "NGC752", "NGC1039", "NGC1342", "NGC1647"]

clustername = name_list[1:]
for clustername in name_list[1:] :
    RADIUS       = 3.0
    errtol       = 0.2
    dump_to_file = True

    ## Read the data and do the conversion

    source = gu.source(clustername, RADIUS, errtol)
    source.query(dump_to_file)
    #source.read_votable(voname)
    source.convert_filter_data(without_mag=True)
    source.plot_information(size=0.005)

# %%
## Read the data and do the conversion
# NGC6625, Collinder107, NGC2252, NGC2682, Collinder65, Collinder21, NGC6811, Turner 5, Sco OB4
clustername = "NGC1647"
RADIUS=6.;errtol=0.2;dump_to_file = True
for clustername, RADIUS, distmax in zip(["NGC1647"],[4.0],[900]) :
    source = gu.source(clustername, RADIUS, errtol)
    source.query(dump_to_file,distmax)
    #source.read_votable(voname)
    source.convert_filter_data(without_mag=True)
    source.plot_information(size=0.01)
# Out:
# SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),                                      CIRCLE('ICRS',71.4792000000,19.1150000000,4.0000000000)) = 1                                      AND abs(pmra_error/pmra)<  0.200000  AND abs(pmdec_error/pmdec)< 0.2000000000                                     AND abs(parallax_error/parallax)< 0.2000000000                                     AND 1000./parallax < 900.0;
# ## NGC1647-4.0deg-0.2err.vot created
# ## Query for NGC1647 done
# ## Total stars: 39435
# ## Density star per pc^3: 0.01056
#
# ## Conversion done...
# ## Stars selected: 38740

# %%
#source.convert_to_cartesian()
source.plot_information(size=0.0001,cartesian=True)

# %%
#ilabel = ilabel_[0]
size = 0.1
import numpy as np
import matplotlib.pyplot as plt
x=300

plt.figure(figsize=(19,9))                
for i_x, i_y, i in zip((1,2),(0,0),(1,2)) :
    plt.subplot(1,2,i)
    if i <= 2 : plt.title(source.name, fontsize=20)
    plt.scatter(source.dfcart[:,i_x],source.dfcart[:,i_y],s=size,c='k')
    #plt.scatter(source.dfcart[ilabel,i_x],source.dfcart[ilabel,i_y],s=size*300,c='r')
    plt.xlabel(gu.data_name[i_x], fontsize=25)
    plt.ylabel(gu.data_name[i_y], fontsize=25)
    plt.ylim(512-x,632+x)
    plt.xlim(-30,30)
plt.show()
