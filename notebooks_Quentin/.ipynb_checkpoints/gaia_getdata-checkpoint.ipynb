# %%
import sys, os
sys.path.append('C:\\Users\Quentin\\Documents\\ALMA_CHILI\\gaia-shock\\src')

## directory
rootdir = r'C:\Users\Quentin\Documents\ALMA_CHILI'
wdir    = r'%s\products'%(rootdir)
#notedir = r'%s\gaia-shock\notebooks_Quentin'%(rootdir)

os.chdir(wdir)  # to change the current directory

import gaia_utils_quentin as gu
# Out:
# Created TAP+ (v1.0.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443

# %%
name_list = ["M67", "NGC2516", "NGC752", "NGC1039", "NGC1342", "NGC1647"]

for i in (3,4,5) :
    clustername = name_list[i]
    RADIUS       = 3.0
    errtol       = 0.1
    dump_to_file = True

    ## Read the data and do the conversion

    source = gu.source(clustername, RADIUS, errtol)
    source.query(dump_to_file)
    #source.read_votable(voname)
    source.convert_filter_data(without_mag=True)
# Out:
# SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),                                      CIRCLE('ICRS',40.5208000000,42.7617000000,3.0000000000)) = 1                                      AND abs(pmra_error/pmra)<  0.100000  AND abs(pmdec_error/pmdec)< 0.1000000000                                     AND abs(parallax_error/parallax)< 0.1000000000;
# ## NGC1039-3.0deg-0.1err.vot created
# ## Query for NGC1039 done
# ## Total stars: 30131
#
# ## Conversion done...
# ## Stars selected: 29200
# SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),                                      CIRCLE('ICRS',52.9083000000,37.3767000000,3.0000000000)) = 1                                      AND abs(pmra_error/pmra)<  0.100000  AND abs(pmdec_error/pmdec)< 0.1000000000                                     AND abs(parallax_error/parallax)< 0.1000000000;
# ## NGC1342-3.0deg-0.1err.vot created
# ## Query for NGC1342 done
# ## Total stars: 29531
#
# ## Conversion done...
# ## Stars selected: 28090
# SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),                                      CIRCLE('ICRS',71.4792000000,19.1150000000,3.0000000000)) = 1                                      AND abs(pmra_error/pmra)<  0.100000  AND abs(pmdec_error/pmdec)< 0.1000000000                                     AND abs(parallax_error/parallax)< 0.1000000000;
# ## NGC1647-3.0deg-0.1err.vot created
# ## Query for NGC1647 done
# ## Total stars: 24657
#
# ## Conversion done...
# ## Stars selected: 23890

# %%
## Read the data and do the conversion

source = gu.source(clustername, RADIUS, errtol)
source.query(dump_to_file)
#source.read_votable(voname)
source.convert_filter_data(without_mag=True)
# Out:
# SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),                                      CIRCLE('ICRS',29.4208000000,37.7850000000,3.0000000000)) = 1                                      AND abs(pmra_error/pmra)<  0.100000  AND abs(pmdec_error/pmdec)< 0.1000000000                                     AND abs(parallax_error/parallax)< 0.1000000000;
# ## NGC752-3.0deg-0.1err.vot created
# ## Query for NGC752 done
# ## Total stars: 27683
#
# ## Conversion done...
# ## Stars selected: 26760

# %%
source.convert_filter_data(without_mag=True)
source.plot_information(size=0.01)
# Out:
# ## Conversion done...
# ## Stars selected: 26760
