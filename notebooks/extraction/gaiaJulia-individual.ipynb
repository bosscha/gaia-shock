# %% [markdown]
# ### Individual solution with the plots
#
# The  velocity corrections (p, rvel) for the differential movements in the galaxy from Conrad (2015) is disconnected for consistency.

# %%
using PyCall
using Distributions
using Statistics

using Distances
using Random , Formatting
using AstroLib
using TSne

rootdir = "/home/stephane/Science/GAIA"

push!(LOAD_PATH,"$rootdir/master/src")
using GaiaClustering

import PyPlot

@pyimport astroquery.vizier as vizier
@pyimport astropy.units as u
@pyimport astropy.coordinates as coord


## directory
wdir    = "$rootdir/products"
plotdir = "$rootdir/products/test"

cd(wdir)

mutable struct twomass
    J::Array{Float64}
    Jerr::Array{Float64}
    H::Array{Float64}
    Herr::Array{Float64}
    K::Array{Float64}
    Kerr::Array{Float64}
end
# Out:
# ┌ Warning: `@pyimport foo` is deprecated in favor of `foo = pyimport("foo")`.
# │   caller = _pywrap_pyimport(::PyObject) at PyCall.jl:407
# └ @ PyCall /home/stephane/.julia/packages/PyCall/ttONZ/src/PyCall.jl:407

# %%
#########
function _filter_data(gaia, dist_range = [0., 2000], vra_range = [-250,250], vdec_range = [-250.,250], 
        mag_range =[-1e9, 1e9])
########
    ngaia = length(gaia)
    
    println("## testing galactic pm")
    
    lgal = zeros(ngaia)
    bgal = zeros(ngaia) 
    ra = zeros(ngaia)
    dec= zeros(ngaia)
    distance = zeros(ngaia)  
    pmra = zeros(ngaia)
    pmdec = zeros(ngaia)    
    parallax = zeros(ngaia)
    vra = zeros(ngaia)
    vdec = zeros(ngaia)    
    g = zeros(ngaia)
    rp = zeros(ngaia)     
    bp = zeros(ngaia) 
    parallax_error = zeros(ngaia)
    pmra_error     = zeros(ngaia)
    pmdec_error    = zeros(ngaia)
    radialvel      = zeros(ngaia)
    exfact_sub     = zeros(ngaia)
    
    ## Galactic proper motion
    pml = zeros(ngaia)
    pmb = zeros(ngaia)
    
    for i in 1:ngaia

        
        lgal[i]     = convert(Float64,gaia[i]["l"])
        bgal[i]     = convert(Float64,gaia[i]["b"])
        ra[i]       = convert(Float64,gaia[i]["ra"])
        dec[i]      = convert(Float64,gaia[i]["dec"])
        distance[i] = 1000. / convert(Float64,gaia[i]["parallax"])
        parallax[i] = convert(Float64,gaia[i]["parallax"])
        pmra[i]     = convert(Float64,gaia[i]["pmra"])
        pmdec[i]    = convert(Float64,gaia[i]["pmdec"])
        vra[i]      = 4.74e-3 * pmra[i]  * distance[i]
        vdec[i]     = 4.74e-3 * pmdec[i] * distance[i]
        ### errors.
        parallax_error[i]  = convert(Float64,gaia[i]["parallax_error"])
        pmra_error[i]  = convert(Float64,gaia[i]["pmra_error"])
        pmdec_error[i] = convert(Float64,gaia[i]["pmdec_error"])
        
        g[i]        = convert(Float64,gaia[i]["phot_g_mean_mag"])
        rp[i]       = convert(Float64,gaia[i]["phot_rp_mean_mag"])
        bp[i]       = convert(Float64,gaia[i]["phot_bp_mean_mag"])
        ef          = convert(Float64,gaia[i]["phot_bp_rp_excess_factor"])
        exfact_sub[i] = ef 
        radialvel[i] = convert(Float64,gaia[i]["radial_velocity"])
        
        ## testing
        muG = PM_equatorial2galactic(pmra[i],pmdec[i]  , ra[i] , dec[i] , lgal[i])
        pml[i] = muG[1]
        pmb[i] = muG[2]
        vra[i]      = 4.74e-3 * pml[i]  * distance[i]
        vdec[i]     = 4.74e-3 * pmb[i]  * distance[i]
    end
    
    ## Filtering ...
    i1 =  distance .> dist_range[1]
    i2 =  distance .< dist_range[2]
    i3 =  vra .> vra_range[1]
    i4 =  vra .< vra_range[2]
    i5 =  vdec .> vdec_range[1]
    i6 =  vdec .< vdec_range[2]
    i7 = g  .> mag_range[1]
    i8 = g  .< mag_range[2]
    i9  = rp  .> mag_range[1]
    i10 = rp  .< mag_range[2]
    i11  = bp  .> mag_range[1]
    i12  = bp  .< mag_range[2]
    
   
    ifinal = i1 .& i2 .& i3 .& i4 .& i5 .& i6 .& i7 .& i8 .& i9 .& i10 .& i11 .& i12 
    
    ## G magnitude
     # gbar =  g[ifinal] - 5. * log10.(distance[ifinal]) + 17.
    gbar =  g[ifinal] - 5 .* log10.(distance[ifinal]) .+ 17.
    
    ## Df of the filtered dat
    ndata = length(distance[ifinal])
    s = GaiaClustering.Df(ndata, zeros(8,ndata), zeros(11,ndata) , zeros(8,ndata) )

    
    s.data[1,:] = lgal[ifinal]
    s.data[2,:] = bgal[ifinal]
    s.data[3,:] = distance[ifinal]
    s.data[4,:] = vra[ifinal]
    s.data[5,:] = vdec[ifinal]
    s.data[6,:] = gbar
    s.data[7,:] = g[ifinal] .- rp[ifinal]
    s.data[8,:] = bp[ifinal] .- g[ifinal]
    
    
    s.raw[1,:] = ra[ifinal]
    s.raw[2,:] = dec[ifinal]
    s.raw[3,:] = lgal[ifinal]
    s.raw[4,:] = bgal[ifinal]
    s.raw[5,:] = parallax[ifinal]
    s.raw[6,:] = pmra[ifinal]
    s.raw[7,:] = pmdec[ifinal]
    s.raw[8,:] = gbar
    s.raw[9,:] = rp[ifinal]
    s.raw[10,:] = bp[ifinal] 
    s.raw[11,:] = radialvel[ifinal]
    
    
    ## Errors ..
    s.err[1,:] = parallax_error[ifinal]
    s.err[4,:] = pmra_error[ifinal]
    s.err[5,:] = pmdec_error[ifinal]
    
    println("## Filtering done ...")
    println("## Stars selected: $ndata")
    
    return(s, exfact_sub[ifinal])
end
# Out:
# _filter_data (generic function with 5 methods)

# %%
## Flux excess limit from GAIA DR2 article
## The flux excess should be below that curve for good photometry
## Evans et al. 2018
##

function fluxexcess_limit(bp, rp )
    limit = 1.3 + 0.06 * (bp-rp)^2
    return(limit)
end
# Out:
# fluxexcess_limit (generic function with 1 method)

# %%
## Transform PM from equatorial to galactic system.
## See Poleski 1997 / arXiv
## PM,,corr is from Conrad (2015)

function PM_equatorial2galactic(μα , μδ , α , δ , l )
    αG = 192.85948
    δG = 27.12825
    
    C1 = sind(δG)*cosd(δ) - cosd(δG)*sind(δ)*cosd(α - αG)
    C2 =  cosd(δG)*sind(α - αG)
    k = 1 / sqrt(C1^2 + C2^2)
    A = k * [C1 C2 ; -C2 C1]
    PMG = A * [μα ; μδ ]
    
    ## PM along gal. lat. corrected for differential velocity 
    ## Oort constants
    A , B = (14.5 , -13.) ./ 4.74
    PMG[1] =  PMG[1] - (A*cosd(2l) + B)
    
    return(PMG)
end
# Out:
# PM_equatorial2galactic (generic function with 1 method)

# %%
function _getdata(filevot , wghtblck)
    voname = filevot

    data       = read_votable(voname)
    df         = filter_data(data)
    dfcart     = add_cartesian(df)
    blck       = [[1,2,3],[4,5], [6,7,8]]
    # wghtblck   = [4.0,5.0,1.0]
    # wghtblck   = [3.03, 9.05, 1.83]
    norm       = "identity"

    dfcartnorm , scale8 = normalization_PerBlock(dfcart, blck, wghtblck , norm, false) 
    return(df, dfcart , dfcartnorm)
end
# Out:
# _getdata (generic function with 1 method)

# %%
## Get the 2Mass Magnitudes

function _get_2MASS(indx, df::GaiaClustering.Df)
    s = length(indx)
    tm = twomass(zeros(s),zeros(s),zeros(s),zeros(s),zeros(s),zeros(s)) 
    
    for i in 1:s
        c = coord.SkyCoord(ra= df.raw[1,indx[i]], dec=df.raw[2,indx[i]]  , unit=(u.deg, u.deg), frame="icrs")
        res = vizier.Vizier[:query_region](c , width="5s",catalog="II/246")
        if length(res) > 0
            tm.J[i]    = res[1][1][4][1]
            tm.Jerr[i] = res[1][1][5][1]
            tm.H[i]    = res[1][1][6][1]
            tm.Herr[i] = res[1][1][7][1]
            tm.K[i]    = res[1][1][8][1]
            tm.Kerr[i] = res[1][1][9][1]            
        end
    end
    return(tm)
end
# Out:
# _get_2MASS (generic function with 1 method)

# %%
## label from the dbscan labels with maximum stars
function _find_cluster_label(labels)
    let
    i = 1 ; nmax = 0 ; ilabel = 1
        for ilab in labels
            nlab = length(ilab)
            if nlab > nmax
                ilabel = i
                nmax= nlab
            end
            i += 1
        end
    return(ilabel, nmax)
    end
end


function _plot_cluster(plotdir, voname, indx, sc::GaiaClustering.SCproperties, tm::twomass , df::GaiaClustering.Df, showplot = true , cmap = "gist_stern")

    PyPlot.plt[:figure](figsize=(12.0,12.0))

    PyPlot.plt[:subplot](3, 3, 1 , xlim = [-20,20] , ylim = [-20,20])
    xx = df.data[2,indx]
    yy = df.data[3,indx]
    ## A circle of radius std(z)
    # xc = mean(df.data[2,indx]) ; yc = mean(df.data[3,indx])
    # circle1 = PyPlot.plt[:Circle](0.,0.,1.)
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("Y (pc)")
    PyPlot.plt[:ylabel]("Z (pc)")
    PyPlot.plt[:grid](true)
    
    PyPlot.plt[:subplot](3, 3, 2 , ylim = [-20,20])
    xx = df.data[1,indx]
    yy = df.data[3,indx]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("X (pc)")
    PyPlot.plt[:ylabel]("Z (pc)")
    PyPlot.plt[:grid](true)
    
    PyPlot.plt[:subplot](3, 3, 4 , xlim = [-20,20])
    xx = df.data[2,indx]
    yy = df.data[1,indx]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("Y (pc)")
    PyPlot.plt[:ylabel]("X (pc)")
    PyPlot.plt[:grid](true)
    
    PyPlot.plt[:subplot](3, 3, 3 )
    xx = df.data[1,indx]
    yy = df.raw[13,indx]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("X(pc)")
    PyPlot.plt[:ylabel]("Vrad (km/s)")
    PyPlot.plt[:grid](true)    
        
    PyPlot.plt[:subplot](3, 3, 5)
    PyPlot.plt[:axis]("off")
    ## text to display
    text =[]
    v = sc.nstars ; txt = "N stars   : $v" ; push!(text,txt)
    v = fmt("3.1f",sc.distance) ; txt = "Distance  : $v (pc)" ; push!(text,txt)
    v = fmt("3.3f",sc.l) ; txt = "l         : $v (degree)" ; push!(text,txt)
    v = fmt("3.3f",sc.b) ; txt = "b         : $v (degree)" ; push!(text,txt)
    v = fmt("3.2f", sc.vl) ; txt = "Vl      : $v (km/s)" ; push!(text,txt)
    v = fmt("3.2f",sc.vb) ; txt = "Vb      : $v (km/s)"; push!(text,txt)
    v = fmt("3.2f",sc.vrad) ; txt = "Vradial   : $v (km/s)"; push!(text,txt)    
    v = fmt("3.2f",sc.xdisp) ; txt = "X disp.   : $v (pc)" ; push!(text,txt)
    v = fmt("3.2f",sc.ydisp) ; txt = "Y disp.   : $v (pc)" ; push!(text,txt)
    v = fmt("3.2f",sc.zdisp) ; txt = "Z disp.   : $v (pc)" ; push!(text,txt)
    v = fmt("3.2f",sc.vldisp) ; txt = "Vl disp. : $v (km/s)" ; push!(text,txt)
    v = fmt("3.2f",sc.vbdisp) ; txt = "Vb disp.: $v (km/s)" ; push!(text,txt)
    v = fmt("3.2f",sc.vraddisp) ; txt = "Vradial disp.: $v (km/s)" ; push!(text,txt)
    show_text(-0.01,0.0, text , 1.0)
    
    PyPlot.plt[:subplot](3, 3, 7 )
    PyPlot.plt[:axis]("on")    
    xx = df.data[7,indx]
    yy = -df.data[6,indx]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("G-Rp")
    PyPlot.plt[:ylabel]("G")
    PyPlot.plt[:grid](true)
    
    PyPlot.plt[:subplot](3, 3, 8 )
    xx = df.data[4,indx]
    yy = df.data[5,indx]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:xlabel]("Vl (km/s)")
    PyPlot.plt[:ylabel]("Vb (km/s)")
    PyPlot.plt[:grid](true)
    
    PyPlot.plt[:subplot](3, 3, 9 , ylim =[-17,-6.])
    yy = -tm.J[:]
    xx = tm.J[:] .- tm.K[:]
    PyPlot.plt[:scatter](xx, yy , s = 1.0 )
    PyPlot.plt[:ylabel]("J")
    PyPlot.plt[:xlabel]("J-K")
    PyPlot.plt[:grid](true)
    
    
    figname = plotdir*"/"*voname*"-cluster.png"
    PyPlot.plt[:savefig](figname)
    if showplot PyPlot.plt[:show]() end
end
# Out:
# _plot_cluster (generic function with 3 methods)

# %%
function _plot_sne(Y, indx)

    PyPlot.plt[:figure](figsize=(6.0,6.0))
    
    PyPlot.plt[:plot](Y[:,1],Y[:,2], "b.", markersize=1.0)
    PyPlot.plt[:plot](Y[indx,1],Y[indx,2], "r.",markersize=1.0)
    PyPlot.plt[:show]()
end
# Out:
# _plot_sne (generic function with 1 method)

# %%
macro main(votname, check2mass=true)
    Random.seed!(1237)
    println("## Main ...")
    
    wghtblck   = [4.5, 7.8, 2.0]
    eps = 2.2
    min_nei = 7
    min_cl = 18
    println("ϵ : $eps")

    ## Get the cluster data..
    df , dfcart, dfnorm  = _getdata(votname , wghtblck)
    
    ## flux excess factor ###############
    data       = read_votable(votname)
    df1, ef1   = _filter_data(data)
    PyPlot.plt[:plot](df1.raw[10,:].- df1.raw[9,:] ,  ef1, "k.", markersize = 0.5)
    col = 0:500 ./ 100 
    flex = 1.3 .+ 0.06 .* col .* col
    PyPlot.plt[:plot](col, flex, "r-")
    efcheck = fluxexcess_limit.(df1.raw[10,:],df1.raw[9,:]) .- ef1
    indexf = efcheck .> 0.0
    println(size(ef1[indexf]))
    frac = 100. * (1 - size(ef1[indexf])[1] / size(ef1)[1])
    println("## Flux excess factor out (%): $frac")
    
    
    println("## dbscan..")
    labels = clusters(dfnorm.data , eps , 20, min_nei, min_cl)
    labelmax , nmax = find_cluster_label(labels)
    println("## Search for 2MASS counterparts...")
    if check2mass
        tmass = _get_2MASS(labels[labelmax] , df)
    else
        s=1
        tmass= twomass(zeros(s),zeros(s),zeros(s),zeros(s),zeros(s),zeros(s)) 
    end
    
    println("## done.")
    
    println("### $(length(labels)) clusters found.")
    println("### Label solution: $labelmax")
    println("### N stars: $nmax")
    sc = get_properties_SC(labels[labelmax] , df, dfcart)
    println(sc)
    
    #plot_cluster(plotdir, votname, labels[labelmax], sc ,  dfcart )
    _plot_cluster(plotdir, votname, labels[labelmax], sc , tmass,  dfcart )
    
    ## testing tSNE
    println("## testing T-SNE ...")
    X = transpose(df.data[:,labels[labelmax]])
    #X = (A .- mean(A, dims=1)) ./ std(A, dims=1)
    Y = tsne(X, 2, 50, 2000, 20.0 , progress = false);
    println(size(Y))
    _plot_sne(Y , [1])
    
    ## SC kinematics
    println(" ")
    A , B = (14.5 , -13.) ./ 4.74
    kk = (A*cosd(2sc.l) + B)
    println(kk)
    println("pml:",sc.pml)
    println("pmb:",sc.pmb)
    #println(sc.parallax)
    println("## Galactic velocity:")
     u,v,w = gal_uvw(sc.ra, sc.dec, sc.pmra, sc.pmdec, sc.vrad , sc.parallax)
     s1= fmt("3.2f",u) ; println("U: $s1")
     s2= fmt("3.2f",v) ; println("V: $s2")
     s3= fmt("3.2f",w) ; println("W: $s3")
end

@main("test.vot", false)
# Out:
# ## Main ...
# ϵ : 2.2
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = read_votable(::String) at data.jl:40
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:40
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = read_votable(::String) at data.jl:42
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:42
# ## Votable test.vot read
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = read_votable(::String) at data.jl:43
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:43
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = read_votable(::String) at data.jl:47
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:47
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = read_votable(::String) at data.jl:47
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:47
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:80
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:80
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:80
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:80
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:81
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:81
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:81
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:81
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:82
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:82
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:82
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:82
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:83
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:83
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:83
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:83
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:84
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:84
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:84
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:84
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:85
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:85
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:85
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:85
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:86
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:86
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:86
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:86
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:87
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:87
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:87
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:87
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:98
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:98
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:98
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:98
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:101
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:101
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:101
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:101
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:102
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:102
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:102
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:102
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:103
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:103
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:103
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:103
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:107
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:107
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:107
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:107
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:108
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:108
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:108
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:108
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:109
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:109
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at data.jl:109
# └ @ GaiaClustering /home/stephane/Science/GAIA/master/src/data.jl:109
# ## Filtering done ...
# ## Stars selected: 82259
# ## Cartesian transformation done ...
# ## Normalization identity done...
# ### [1pc,1pc,1pc,1km/s,1km/s,1mag,1mag,1mag] equivalent to [0.322724, 0.322724, 0.322724, 0.559388, 0.559388, 0.143433, 0.143433, 0.143433]
# ##
# ## Votable test.vot read
# ## testing galactic pm
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:35
# └ @ Main ./In[2]:35
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:35
# └ @ Main ./In[2]:35
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:36
# └ @ Main ./In[2]:36
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:36
# └ @ Main ./In[2]:36
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:37
# └ @ Main ./In[2]:37
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:37
# └ @ Main ./In[2]:37
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:38
# └ @ Main ./In[2]:38
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:38
# └ @ Main ./In[2]:38
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:39
# └ @ Main ./In[2]:39
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:39
# └ @ Main ./In[2]:39
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:40
# └ @ Main ./In[2]:40
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:40
# └ @ Main ./In[2]:40
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:41
# └ @ Main ./In[2]:41
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:41
# └ @ Main ./In[2]:41
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:42
# └ @ Main ./In[2]:42
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:42
# └ @ Main ./In[2]:42
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:46
# └ @ Main ./In[2]:46
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:46
# └ @ Main ./In[2]:46
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:47
# └ @ Main ./In[2]:47
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:47
# └ @ Main ./In[2]:47
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:48
# └ @ Main ./In[2]:48
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:48
# └ @ Main ./In[2]:48
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:50
# └ @ Main ./In[2]:50
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:50
# └ @ Main ./In[2]:50
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:51
# └ @ Main ./In[2]:51
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:51
# └ @ Main ./In[2]:51
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:52
# └ @ Main ./In[2]:52
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:52
# └ @ Main ./In[2]:52
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:53
# └ @ Main ./In[2]:53
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:53
# └ @ Main ./In[2]:53
# ┌ Warning: `getindex(o::PyObject, i::Integer)` is deprecated, use `get(o, i - 1)` instead.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:55
# └ @ Main ./In[2]:55
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = _filter_data(::PyObject, ::Array{Float64,1}, ::Array{Int64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at In[2]:55
# └ @ Main ./In[2]:55
# ## Filtering done ...
# ## Stars selected: 82256
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = @main(::LineNumberNode, ::Module, ::Any, ::Any) at In[9]:17
# └ @ Main ./In[9]:17
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = @main(::LineNumberNode, ::Module, ::Any, ::Any) at In[9]:20
# └ @ Main ./In[9]:20
# (73998,)
# ## Flux excess factor out (%): 10.039389223886408
# ## dbscan..
# ## Search for 2MASS counterparts...
# ## done.
# ### 6 clusters found.
# ### Label solution: 4
# ### N stars: 1224
# GaiaClustering.SCproperties(1224, 1047.2646582789619, 150.57807109729134, -60.053619030717144, 283.2635543241098, -3.8093111975689964, 0.9565382826678311, -7.3615748631786255, 3.7845680654447538, -8.1602171230477, -1.3902429628804591, -40.5051463289067, -6.904093312990527, -0.8465461897510088, 43.974611228528914, 5.764962227962952, 4.668402214972916, 2.05790124541952, 1.2545111428275397, 8.96367294769669)
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:20
# └ @ Main ./In[7]:20
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:22
# └ @ Main ./In[7]:22
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:28
# └ @ Main ./In[7]:28
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:29
# └ @ Main ./In[7]:29
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:30
# └ @ Main ./In[7]:30
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:31
# └ @ Main ./In[7]:31
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:33
# └ @ Main ./In[7]:33
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:36
# └ @ Main ./In[7]:36
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:37
# └ @ Main ./In[7]:37
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:38
# └ @ Main ./In[7]:38
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:39
# └ @ Main ./In[7]:39
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:41
# └ @ Main ./In[7]:41
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:44
# └ @ Main ./In[7]:44
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:45
# └ @ Main ./In[7]:45
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:46
# └ @ Main ./In[7]:46
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:47
# └ @ Main ./In[7]:47
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:49
# └ @ Main ./In[7]:49
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:52
# └ @ Main ./In[7]:52
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:53
# └ @ Main ./In[7]:53
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:54
# └ @ Main ./In[7]:54
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:55
# └ @ Main ./In[7]:55
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:57
# └ @ Main ./In[7]:57
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:58
# └ @ Main ./In[7]:58
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:76
# └ @ Main ./In[7]:76
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:77
# └ @ Main ./In[7]:77
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:80
# └ @ Main ./In[7]:80
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:81
# └ @ Main ./In[7]:81
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:82
# └ @ Main ./In[7]:82
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:83
# └ @ Main ./In[7]:83
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:85
# └ @ Main ./In[7]:85
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:88
# └ @ Main ./In[7]:88
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:89
# └ @ Main ./In[7]:89
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:90
# └ @ Main ./In[7]:90
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:91
# └ @ Main ./In[7]:91
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:93
# └ @ Main ./In[7]:93
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:96
# └ @ Main ./In[7]:96
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:97
# └ @ Main ./In[7]:97
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:98
# └ @ Main ./In[7]:98
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:99
# └ @ Main ./In[7]:99
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:103
# └ @ Main ./In[7]:103
# ## testing T-SNE ...
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_cluster(::String, ::String, ::Array{Int64,1}, ::GaiaClustering.SCproperties, ::twomass, ::GaiaClustering.Df, ::Bool, ::String) at In[7]:104
# └ @ Main ./In[7]:104
# ┌ Warning: implicit `dims=2` argument now has to be passed explicitly to specify that distances between columns should be computed
# │   caller = ip:0x0
# └ @ Core :-1
# (1224, 2)
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_sne(::Array{Float64,2}, ::Array{Int64,1}) at In[8]:3
# └ @ Main ./In[8]:3
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_sne(::Array{Float64,2}, ::Array{Int64,1}) at In[8]:5
# └ @ Main ./In[8]:5
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_sne(::Array{Float64,2}, ::Array{Int64,1}) at In[8]:6
# └ @ Main ./In[8]:6
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _plot_sne(::Array{Float64,2}, ::Array{Int64,1}) at In[8]:7
# └ @ Main ./In[8]:7
# -5.4796383267264925
# pml:-8.1602171230477
# pmb:-1.3902429628804591
# ## Galactic velocity:
# U: 39.66
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x1200 with 8 Axes>)
# PyPlot.Figure(PyObject <Figure size 600x600 with 1 Axes>)
# V: -8.01
# W: -6.82
