# %% [markdown]
# ### Tests
# Use of the agglomerative clustering with HR diagram.
#
# We test here metrics to detect good solutions for clustering

# %%
import sys, os
sys.path.append('../../src')

from numba import jit

import matplotlib.pyplot as plt
from pylab import rcParams
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
import pickle

from math import ceil
import math
import gaia_utils as gu
from sklearn import cluster
from sklearn.neighbors import kneighbors_graph
from astroML.correlation import two_point
from astroML.correlation import bootstrap_two_point_angular

# %matplotlib inline

## directory
rootdir = "/home/stephane/Science/GAIA"
wdir    = "%s/products"%(rootdir)
datadir = "%s/master/notebooks/data"%(rootdir)

os.chdir(wdir)
rcParams['figure.figsize'] = 9, 6
###################################

clustername = "NGC 1647"
# voname = 'NGC 752-1.0deg.vot'
# voname = 'NGC 2682-3.0deg.vot'
voname = 'NGC 1647-2.0deg.vot'
RADIUS   = 2.0
kCluster = 10
votable_disk = False
distclust = 572.0
WEIGHT = [3.,3.,11.,5.,5., 2., 2., 2.]
WEIGHT = [4.87863010104081, 4.87863010104081, 4.306272782136562, 2.5786331381796077, 2.5786331381796077, 1.4117964989460319, 1.4117964989460319, 1.4117964989460319]

## dscan
eps = 0.05
min_samples = 30
## Ward
neighbors = 30

# %%
## plot2D and plot3D


def plot2d(df, labels, ilab, cmap = "gist_stern" ,color = False):
    
    rcParams['figure.figsize'] = 14, 14
    f, axarr = plt.subplots(2, 2)
    
    if color:
        axarr[0,0].scatter(df[np.where(labels == ilab),0],df[np.where(labels == ilab),1],  s = 0.5, c= df[np.where(labels == ilab),2], cmap=cmap )
    else:
        axarr[0,0].scatter(df[np.where(labels == ilab),0],df[np.where(labels == ilab),1],  s = 0.5, c = "k")
    axarr[0,0].set_xlabel("l")
    axarr[0,0].set_ylabel("b")
    
    axarr[1,0].scatter(df[np.where(labels == ilab),0],df[np.where(labels == ilab),2] , s=0.5, c= df[np.where(labels == ilab),2], cmap=cmap)
    axarr[1,0].set_xlabel("l")
    axarr[1,0].set_ylabel("d (pc)")
    
    
    axarr[0,1].scatter(df[np.where(labels == ilab),3],df[np.where(labels == ilab),4] , s= 0.5, c= df[np.where(labels == ilab),2], cmap=cmap)
    axarr[0,1].set_xlabel("Vdra")
    axarr[0,1].set_ylabel("Vdec")
    
    axarr[1,1].scatter(df[np.where(labels == ilab),6],df[np.where(labels == ilab),5] , s = 0.5, c= df[np.where(labels == ilab),2], cmap=cmap)
    axarr[1,1].set_xlabel("G-R")
    axarr[1,1].set_ylabel("G")
    axarr[1,1].set_xlim(-1.,1.5)
    axarr[1,1].set_ylim(27.,10)
    
    plt.show()

# %%
## astrometric conversion
## 
def convert_to_cartesian(lgal, bga, dist, offCenter = [0., 0.]):
    "Convert ra,dec (ICRS) and distance (pc) to Cartesian reference. Off is the offset in Lgal,Bgal"
    
    xx = np.zeros(len(lgal))
    yy = np.zeros(len(lgal))
    zz = np.zeros(len(lgal))
    
    lgalOff = lgal - offCenter[0]
    bgalOff = bgal - offCenter[1]
    
    print(offCenter[0])
    print(offCenter[1])
    print(min(lgalOff))
    print(max(lgalOff))
    print(min(bgalOff))
    print(max(bgalOff))
    
    
    for i in range(len(lgal)):
        c = coord.SkyCoord(l=lgalOff[i]*u.degree, b=bgalOff[i]*u.degree, distance=dist[i]*u.pc, frame='galactic')
        
        xx[i] = c.cartesian.x.value
        yy[i] = c.cartesian.y.value
        zz[i] = c.cartesian.z.value
        
    print("## XX")
    print("min, max: %f , %f"%(min(xx),max(xx)))
    print("## YY")
    print("min, max: %f , %f"%(min(yy),max(yy)))
    print("## ZZ")
    print("min, max: %f , %f"%(min(zz),max(zz)))  
        
    return(xx,yy,zz)

# %%
## Read the data and do the conversion


source = gu.source(clustername)
source.weight = WEIGHT
#source.query(RADIUS, errtol = 0.2, dump = True)
source.read_votable(voname)
source.convert_filter_data(mag_range = [0., 40])
source.normalization_normal()
#source.normalization_minmax()
# Out:
# ## NGC 1647-2.0deg.vot read...
# ## Total stars: 20719
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# ()

# %% [markdown]
# ### Metrics
#
# Metric to quantify goodness-of-solution for the clustering.

# %%
def metric1(df, labels, APERTURE = 0.2 , MAXRADIUS = 1. , NBOOTSTRAP =20 ):
    "Using the density contrat assuming the OC is at the center"
    
    xc   = np.mean(df[:,0])
    yc   = np.mean(df[:,1]) 
    
    nlab = max(labels)+1
    aper2 = APERTURE*APERTURE
    metric = {}
    metric['label'] = []
    metric['Q'] = []
    metric['Q_err'] = []
    
    for ilab in range(nlab):
        
        dflab = df[np.where(labels == ilab),:][0]
        radii = (dflab[:,0]- xc)*(dflab[:,0]- xc)+(dflab[:,1]- yc)*(dflab[:,1]- yc)
        nclust = radii[np.where(radii < aper2)]
        dens_clust = len(nclust) / aper2
        
        angle_out = np.random.uniform(0., 2*math.pi, NBOOTSTRAP)
        rad_out   = np.random.uniform(APERTURE,MAXRADIUS-APERTURE, NBOOTSTRAP)
        
        Q_c = np.zeros(NBOOTSTRAP)
        
        for k in range(NBOOTSTRAP): 
            xi = xc + rad_out[k]*math.cos(angle_out[k])
            yi = yc + rad_out[k]*math.sin(angle_out[k])
            radii_out = (dflab[:,0]- xi)*(dflab[:,0]- xi)+(dflab[:,1]- yi)*(dflab[:,1]- yi)
            nout = radii_out[np.where(radii_out < aper2)]
            dens_out_k = max(1,len(nout)) / aper2
            Q_c[k] = dens_clust / dens_out_k
            
        metric['label'].append(ilab)
        metric['Q'].append(np.mean(Q_c))
        metric['Q_err'].append(np.std(Q_c))
        
    return(metric)
                          
@jit
def metric2(df, labels, APERTURE = 0.2 , MAXRADIUS = 1. , NBOOTSTRAP = 50 , SIGCLIP = 0.):
    "Using the density contrat assuming the OC is at the center and the distribution around is regular (no holes)"
        
    epsilon = 0.1
    xc   = np.mean(df[:,0])
    yc   = np.mean(df[:,1]) 
    
    nlab = max(labels)+1
    aper2 = APERTURE*APERTURE
    metric = {}
    metric['label'] = []
    metric['Q'] = []
    metric['Q_err'] = []
    
    for ilab in range(nlab):
        
        dflab = df[np.where(labels == ilab),:][0]
        radii = (dflab[:,0]- xc)*(dflab[:,0]- xc)+(dflab[:,1]- yc)*(dflab[:,1]- yc)
        nclust = radii[np.where(radii < aper2)]
        dens_clust = len(nclust) / aper2
        
        angle_out = np.random.uniform(0., 2*math.pi, NBOOTSTRAP)
        rad_out   = np.random.uniform(APERTURE,MAXRADIUS-APERTURE, NBOOTSTRAP)
        
        nstarsout = np.zeros(NBOOTSTRAP)
        
        for k in range(NBOOTSTRAP): 
            xi = xc + rad_out[k]*math.cos(angle_out[k])
            yi = yc + rad_out[k]*math.sin(angle_out[k])
            radii_out = (dflab[:,0]- xi)*(dflab[:,0]- xi)+(dflab[:,1]- yi)*(dflab[:,1]- yi)
            nout = radii_out[np.where(radii_out < aper2)]
            nstarsout[k] = len(nout) + np.random.uniform(1., 1.+ epsilon)
                
        outmean = np.mean(nstarsout)
        outstd  = np.std(nstarsout)
        
        nstar_filtered = np.where( (nstarsout - outmean)/ outstd > SIGCLIP )

        dens_out = nstarsout[nstar_filtered] / aper2
        Q_c = np.zeros(len(dens_out))
        Q_c = dens_clust / dens_out
        
        metric['label'].append(ilab)
        metric['Q'].append(np.mean(Q_c))
        metric['Q_err'].append(np.std(Q_c))
        
    return(metric)

# %%
def iter_parameters(angmin,angmax,dmin,dmax,vmin,vmax,magmin,magmax, kmin, kmax ,ntrial, von = "test.vot", radius = 1):
    "Range of the weight for each group of parameters"
        
    s = gu.source(clustername)
    s.read_votable(von)

    metric = {}
    angle = np.linspace(angmin,angmax,ntrial)
    distance = np.linspace(dmin,dmax,ntrial)
    vel   = np.linspace(vmin, vmax,ntrial)
    mag   = np.linspace(magmin, magmax,ntrial)
    kclus = range(kmin,kmax)
    
    metric['kmeans'] = {}
    metric['kmeans']['weight'] = []
    metric['kmeans']['metric'] = []
                            
                            
    for a in angle:
        for v in vel:
            for m in mag:
                for d in distance:
                    for k in kclus:
                        WEIGHT = [a,a,d,v,v,m,m,m] 
                        s.weight = WEIGHT
                        s.convert_filter_data(mag_range = [0., 40])
                        s.normalization_normal()
    
                        print(WEIGHT)
        
                        kmeans = cluster.KMeans(n_clusters= kCluster, max_iter = 2000, n_init = 50)
                        kmeans.fit(s.dfnorm)
                        labels_k = kmeans.labels_
                        qk = metric1(s.df, labels_k, APERTURE = 0.2 , MAXRADIUS = radius , NBOOTSTRAP =10 )
                        metric['kmeans']['weight'].append(WEIGHT)
                        metric['kmeans']['metric'].append(qk)
                            
        
    return(metric)

@jit
def random_weighting(angmin,angmax,dmin,dmax,vmin,vmax,magmin,magmax, kmin, kmax , von = "test.vot", radius = 1, NBOOTSTRAP = 100, SCAN = None):
    "Sample with NBOOTSTRAP trial in the weight range to get the Q"
    
    np.random.seed()
    
    s = gu.source(clustername)
    s.read_votable(von)
    
    aper = 0.5
    
    if SCAN == None:
        metric = {}
        metric['kmeans'] = {}
        metric['kmeans']['weight'] = []
        metric['kmeans']['metric'] = []
        metric['ward'] = {}
        metric['ward']['weight'] = []
        metric['ward']['metric'] = []
        metric['spectral'] = {}
        metric['spectral']['weight'] = []
        metric['spectral']['metric'] = []
        metric['dbscan'] = {}
        metric['dbscan']['weight'] = []
        metric['dbscan']['metric'] = []
    else:
        metric = SCAN
        
    
    angle     = np.random.uniform(angmin, angmax, NBOOTSTRAP)
    distance  = np.random.uniform(dmin, dmax, NBOOTSTRAP)
    velocity  = np.random.uniform(vmin, vmax, NBOOTSTRAP)
    magnitude = np.random.uniform(magmin, magmax, NBOOTSTRAP)
    ncluster  = np.random.randint(kmin, kmax, NBOOTSTRAP)
    
            
    for i in range(NBOOTSTRAP):
        WEIGHT = [angle[i],angle[i],distance[i],velocity[i],velocity[i], magnitude[i],magnitude[i], magnitude[i]]
        nclust = ncluster[i]
        
        s.weight = WEIGHT
        s.convert_filter_data(mag_range = [0., 40])
        s.normalization_normal()
    
        print(WEIGHT)
        print(i)
        
        # kmeans
        kmeans = cluster.KMeans(n_clusters= nclust, max_iter = 2000, n_init = 50)
        kmeans.fit(s.dfnorm)
        labels_k = kmeans.labels_
        qk = metric2(s.df, labels_k, APERTURE = aper , MAXRADIUS = 0.9 * radius , NBOOTSTRAP =50 )
        metric['kmeans']['weight'].append(WEIGHT)
        metric['kmeans']['metric'].append(qk)
        print("# k-means done")
                            
        # ward
        connectivity = kneighbors_graph(source.dfnorm, n_neighbors= neighbors, include_self=False)
        # make connectivity symmetric
        connectivity = 0.5 * (connectivity + connectivity.T)
        ward = cluster.AgglomerativeClustering(n_clusters= nclust, linkage='ward', connectivity=connectivity)
        ward.fit(s.dfnorm)
        labels_w = ward.labels_
        qw = metric2(s.df, labels_w, APERTURE = aper , MAXRADIUS = 0.9 * radius , NBOOTSTRAP =50 )
        metric['ward']['weight'].append(WEIGHT)
        metric['ward']['metric'].append(qw)
        print("# Ward done")
        
        # Spectral
        spectral = cluster.SpectralClustering(n_clusters = nclust, eigen_solver='arpack', affinity="nearest_neighbors")
        spectral.fit(s.dfnorm)
        labels_s = spectral.labels_
        qs = metric2(s.df, labels_s, APERTURE = aper , MAXRADIUS = 0.9 * radius , NBOOTSTRAP =50 )
        metric['spectral']['weight'].append(WEIGHT)
        metric['spectral']['metric'].append(qs)
        print("# Spectral done")
        
        # DBSCAN
        eps = 0.05
        min_samples = 30
        dbscan = cluster.DBSCAN(eps, min_samples)
        dbscan.fit(s.dfnorm)
        labels_d = spectral.labels_
        qd = metric2(s.df, labels_d, APERTURE = aper , MAXRADIUS = 0.9 * radius , NBOOTSTRAP =50 )
        metric['dbscan']['weight'].append(WEIGHT)
        metric['dbscan']['metric'].append(qd)
        print("# DBSCAN done")
            
    return(metric)

# %% [markdown]
# ### Clustering

# %%
## testing loop on parameters ..
## Could be very long!!!
## To continue a previous scan..
with open('dataQran.pickle', 'rb') as f:
    previousMetric = pickle.load(f)

# q = iter_parameters(2.,5.,7.,12.,2.,4.,1.,3., 7,8 ,2, von = voname, radius = 2.)
q = random_weighting(1.,7.,3.,15.,1.,7.,1.,5., 5 ,12 , von = voname, radius = 2., NBOOTSTRAP = 100, 
                     SCAN = previousMetric)

with open('dataQran.pickle', 'wb') as f:
    pickle.dump(q, f, pickle.HIGHEST_PROTOCOL)
# Out:
# ## NGC 1647-2.0deg.vot read...
# ## Total stars: 20719
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.9881730247432605, 2.9881730247432605, 3.680993673469235, 2.605072486357936, 2.605072486357936, 1.6682474400761094, 1.6682474400761094, 1.6682474400761094]
# 0
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.10636718554293, 4.10636718554293, 3.777082370222464, 2.9607796470308188, 2.9607796470308188, 1.1833243054604603, 1.1833243054604603, 1.1833243054604603]
# 1
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.463492329314539, 2.463492329314539, 12.374205425203073, 5.442772758673126, 5.442772758673126, 2.7258866212170294, 2.7258866212170294, 2.7258866212170294]
# 2
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.756063346515619, 4.756063346515619, 14.260416831280468, 1.3030178780262294, 1.3030178780262294, 2.517912694324088, 2.517912694324088, 2.517912694324088]
# 3
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.378730633218111, 3.378730633218111, 7.492437130714765, 5.062601107993133, 5.062601107993133, 3.4617014352240814, 3.4617014352240814, 3.4617014352240814]
# 4
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.058191628256074, 5.058191628256074, 9.164244286743394, 5.3681349656048996, 5.3681349656048996, 1.8185107171863564, 1.8185107171863564, 1.8185107171863564]
# 5
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.323647245325315, 5.323647245325315, 3.4623100841623176, 6.226025049945082, 6.226025049945082, 3.445142463328398, 3.445142463328398, 3.445142463328398]
# 6
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.644713986965517, 6.644713986965517, 10.517218787382248, 4.814971638454279, 4.814971638454279, 3.523054576823947, 3.523054576823947, 3.523054576823947]
# 7
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.3977965786992526, 3.3977965786992526, 13.997939135787528, 3.5755051407157215, 3.5755051407157215, 4.432451517215951, 4.432451517215951, 4.432451517215951]
# 8
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.807117592086495, 6.807117592086495, 7.920716681853563, 3.0411681319115997, 3.0411681319115997, 3.5845738913459235, 3.5845738913459235, 3.5845738913459235]
# 9
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.711640124085074, 2.711640124085074, 13.694013308838965, 3.411108927360421, 3.411108927360421, 4.7157382197190465, 4.7157382197190465, 4.7157382197190465]
# 10
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.9966937037239187, 2.9966937037239187, 7.23488976753813, 6.828642371247872, 6.828642371247872, 1.332409713700311, 1.332409713700311, 1.332409713700311]
# 11
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.9165039589588317, 1.9165039589588317, 12.956874843177776, 1.4024147087240424, 1.4024147087240424, 3.9161553518717724, 3.9161553518717724, 3.9161553518717724]
# 12
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.8559930125601087, 2.8559930125601087, 3.5351339146110545, 3.7763377023955105, 3.7763377023955105, 3.1986427481166024, 3.1986427481166024, 3.1986427481166024]
# 13
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.4983634643756165, 6.4983634643756165, 9.240942102263025, 2.6874751924402056, 2.6874751924402056, 2.14428032470132, 2.14428032470132, 2.14428032470132]
# 14
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.076178498768569, 3.076178498768569, 11.230485501219318, 1.5168489239881324, 1.5168489239881324, 1.3617586514558178, 1.3617586514558178, 1.3617586514558178]
# 15
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.608417912213703, 4.608417912213703, 5.677706643006147, 1.31721694049298, 1.31721694049298, 2.037629295455985, 2.037629295455985, 2.037629295455985]
# 16
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.5472401444441726, 2.5472401444441726, 8.83369373116313, 6.985512892791366, 6.985512892791366, 4.624739520134963, 4.624739520134963, 4.624739520134963]
# 17
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.171602301561386, 5.171602301561386, 14.380034609414345, 6.66024674049169, 6.66024674049169, 2.502487153388837, 2.502487153388837, 2.502487153388837]
# 18
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.740589507867631, 6.740589507867631, 5.170974385475873, 5.064085170923363, 5.064085170923363, 1.1969858416022365, 1.1969858416022365, 1.1969858416022365]
# 19
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.7496730703769106, 1.7496730703769106, 9.131198165574638, 6.535817992885761, 6.535817992885761, 4.37275575039348, 4.37275575039348, 4.37275575039348]
# 20
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.181372069397924, 2.181372069397924, 7.561092401077373, 4.489119968810508, 4.489119968810508, 2.159972991965942, 2.159972991965942, 2.159972991965942]
# 21
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.1572927478292327, 1.1572927478292327, 10.77337406975205, 4.216498205327571, 4.216498205327571, 3.01573326646583, 3.01573326646583, 3.01573326646583]
# 22
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.559201801197929, 5.559201801197929, 4.4818090697054505, 2.523605664495923, 2.523605664495923, 4.366123381652283, 4.366123381652283, 4.366123381652283]
# 23
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.255407759329602, 1.255407759329602, 10.22189176513836, 6.286127615905764, 6.286127615905764, 3.9447956438184697, 3.9447956438184697, 3.9447956438184697]
# 24
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.721697018715159, 3.721697018715159, 7.546596428978173, 1.545365785109068, 1.545365785109068, 3.9468492200365985, 3.9468492200365985, 3.9468492200365985]
# 25
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.6528532075156015, 5.6528532075156015, 4.843708821699586, 6.131991222143336, 6.131991222143336, 3.516702377068326, 3.516702377068326, 3.516702377068326]
# 26
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.266656620363272, 2.266656620363272, 9.420790249236523, 6.698837066210864, 6.698837066210864, 1.1186277302371188, 1.1186277302371188, 1.1186277302371188]
# 27
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.814562269002775, 2.814562269002775, 13.95536951366471, 1.5467187515246688, 1.5467187515246688, 4.047648969983037, 4.047648969983037, 4.047648969983037]
# 28
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.065442174905592, 1.065442174905592, 4.366428136762862, 5.760222439432265, 5.760222439432265, 2.614612554836644, 2.614612554836644, 2.614612554836644]
# 29
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.930500439524828, 4.930500439524828, 14.532266380188503, 5.841007841265819, 5.841007841265819, 3.5166813897133693, 3.5166813897133693, 3.5166813897133693]
# 30
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.133934965568758, 6.133934965568758, 11.980458657513813, 6.400582361214565, 6.400582361214565, 4.6955513266301905, 4.6955513266301905, 4.6955513266301905]
# 31
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.707894088203829, 6.707894088203829, 9.962507410981843, 1.6999343839287984, 1.6999343839287984, 3.4031033085921565, 3.4031033085921565, 3.4031033085921565]
# 32
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.5017011756047223, 1.5017011756047223, 7.449764654969816, 1.0505928051407574, 1.0505928051407574, 3.0694411345255554, 3.0694411345255554, 3.0694411345255554]
# 33
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.510404808824745, 4.510404808824745, 9.055137181878344, 2.807222433187187, 2.807222433187187, 2.9651238950463736, 2.9651238950463736, 2.9651238950463736]
# 34
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.748237042758813, 2.748237042758813, 11.242909882956337, 1.1820740313700695, 1.1820740313700695, 4.88457316068759, 4.88457316068759, 4.88457316068759]
# 35
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.6529624414588462, 1.6529624414588462, 7.487812239672136, 3.085642590365861, 3.085642590365861, 1.6602374349070863, 1.6602374349070863, 1.6602374349070863]
# 36
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.7795612145048159, 1.7795612145048159, 9.372335263420654, 2.9737573120919842, 2.9737573120919842, 2.298556012294352, 2.298556012294352, 2.298556012294352]
# 37
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.287082380960128, 3.287082380960128, 14.103518100070534, 1.8535177710566428, 1.8535177710566428, 4.491228625180522, 4.491228625180522, 4.491228625180522]
# 38
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.683717994327855, 2.683717994327855, 7.28526973319085, 2.8236800396335786, 2.8236800396335786, 1.9106563952637434, 1.9106563952637434, 1.9106563952637434]
# 39
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.271880930258847, 2.271880930258847, 4.303368820769762, 5.174659261098529, 5.174659261098529, 1.5289008046626917, 1.5289008046626917, 1.5289008046626917]
# 40
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.4929430370140024, 3.4929430370140024, 14.860132145646572, 2.782044769524669, 2.782044769524669, 3.6920251935000215, 3.6920251935000215, 3.6920251935000215]
# 41
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.3842692500559233, 1.3842692500559233, 11.486293982725517, 4.482465662636609, 4.482465662636609, 3.9394036072541754, 3.9394036072541754, 3.9394036072541754]
# 42
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.600361008067013, 3.600361008067013, 5.215893867227905, 1.7349518236459462, 1.7349518236459462, 4.894722560869397, 4.894722560869397, 4.894722560869397]
# 43
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.493855322579954, 5.493855322579954, 13.49425035643026, 6.164080061029195, 6.164080061029195, 3.5460546073348618, 3.5460546073348618, 3.5460546073348618]
# 44
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.0438661749800464, 3.0438661749800464, 13.44363895591171, 6.644008146084005, 6.644008146084005, 1.9079055508519898, 1.9079055508519898, 1.9079055508519898]
# 45
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.720605084963801, 3.720605084963801, 8.775937440945071, 5.496068092667617, 5.496068092667617, 1.813807299480045, 1.813807299480045, 1.813807299480045]
# 46
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.3512286938682254, 1.3512286938682254, 14.628379171007943, 5.814985265607545, 5.814985265607545, 1.79284966341866, 1.79284966341866, 1.79284966341866]
# 47
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.4473933278895652, 1.4473933278895652, 10.809615602204413, 6.36988399328011, 6.36988399328011, 1.1701173869734887, 1.1701173869734887, 1.1701173869734887]
# 48
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.416315445674127, 4.416315445674127, 13.114704227574135, 6.7438604519431085, 6.7438604519431085, 2.6198023735047227, 2.6198023735047227, 2.6198023735047227]
# 49
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.7199695848797096, 1.7199695848797096, 9.868605491354426, 6.17157650510887, 6.17157650510887, 1.3398026823625933, 1.3398026823625933, 1.3398026823625933]
# 50
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.858939993964861, 4.858939993964861, 5.286566063999125, 3.719560404902829, 3.719560404902829, 3.184433972414459, 3.184433972414459, 3.184433972414459]
# 51
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.4860469102949423, 1.4860469102949423, 5.144196621726038, 3.753905501351526, 3.753905501351526, 2.707936211988029, 2.707936211988029, 2.707936211988029]
# 52
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.500079132785764, 3.500079132785764, 11.801737877309243, 6.9552307118490635, 6.9552307118490635, 4.58042827880484, 4.58042827880484, 4.58042827880484]
# 53
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.4046311463905425, 4.4046311463905425, 4.1540938671829775, 4.311950349678391, 4.311950349678391, 4.429638156077782, 4.429638156077782, 4.429638156077782]
# 54
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.522817178775123, 4.522817178775123, 4.158735392128308, 6.22308649270331, 6.22308649270331, 2.000956241742159, 2.000956241742159, 2.000956241742159]
# 55
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.111599372535748, 6.111599372535748, 3.271959658479074, 4.73089364388731, 4.73089364388731, 3.3328384109367204, 3.3328384109367204, 3.3328384109367204]
# 56
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.509816606098899, 6.509816606098899, 13.563604112021101, 4.973297614898004, 4.973297614898004, 4.264690974097597, 4.264690974097597, 4.264690974097597]
# 57
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.955866684261395, 4.955866684261395, 10.993047207395492, 3.0781732697333446, 3.0781732697333446, 4.20596100938751, 4.20596100938751, 4.20596100938751]
# 58
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.689668278940545, 5.689668278940545, 5.307351057797684, 1.5276508028962623, 1.5276508028962623, 2.926584420557189, 2.926584420557189, 2.926584420557189]
# 59
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.656930134798312, 3.656930134798312, 6.388941502227537, 4.919559698982187, 4.919559698982187, 4.789308017334022, 4.789308017334022, 4.789308017334022]
# 60
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.1184062704482454, 2.1184062704482454, 6.372457606347918, 5.402353931540029, 5.402353931540029, 3.7162681044024577, 3.7162681044024577, 3.7162681044024577]
# 61
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.956140980661382, 6.956140980661382, 3.3209835626657855, 5.373410186147904, 5.373410186147904, 1.8647941395116612, 1.8647941395116612, 1.8647941395116612]
# 62
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.907593651443891, 6.907593651443891, 12.743685989000037, 6.991690964656149, 6.991690964656149, 1.8157279525994694, 1.8157279525994694, 1.8157279525994694]
# 63
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.279384522848183, 3.279384522848183, 7.325392844699911, 5.261788896620902, 5.261788896620902, 1.9385969539486463, 1.9385969539486463, 1.9385969539486463]
# 64
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.94697205317852, 3.94697205317852, 6.820996152862861, 1.2905288701533846, 1.2905288701533846, 3.899617901918738, 3.899617901918738, 3.899617901918738]
# 65
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.705147348320052, 4.705147348320052, 9.789965223904801, 2.487058411488422, 2.487058411488422, 2.4704839516871093, 2.4704839516871093, 2.4704839516871093]
# 66
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.684458191316823, 5.684458191316823, 3.843341364552932, 6.835587873454707, 6.835587873454707, 2.377804776016958, 2.377804776016958, 2.377804776016958]
# 67
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.630197097435886, 4.630197097435886, 3.7855613310648115, 5.880382981166098, 5.880382981166098, 4.8799092218652085, 4.8799092218652085, 4.8799092218652085]
# 68
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.7322775781101263, 2.7322775781101263, 7.767793737682555, 5.891280501035916, 5.891280501035916, 4.854732030226936, 4.854732030226936, 4.854732030226936]
# 69
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.717680264367071, 3.717680264367071, 10.652243530622556, 6.039890922498067, 6.039890922498067, 2.926748203475195, 2.926748203475195, 2.926748203475195]
# 70
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.001565857321899, 3.001565857321899, 8.724622756898222, 3.4630691613998428, 3.4630691613998428, 2.1111553992932524, 2.1111553992932524, 2.1111553992932524]
# 71
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [6.505222801285724, 6.505222801285724, 3.809898676099573, 3.5266712353761274, 3.5266712353761274, 3.28932095475198, 3.28932095475198, 3.28932095475198]
# 72
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.589044171005128, 5.589044171005128, 8.488160707423019, 3.3617163034603954, 3.3617163034603954, 4.6472677793247685, 4.6472677793247685, 4.6472677793247685]
# 73
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.044365234270168, 4.044365234270168, 12.98455906865118, 4.518947696172351, 4.518947696172351, 4.930441223228243, 4.930441223228243, 4.930441223228243]
# 74
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.161713900655399, 4.161713900655399, 13.54474197583195, 1.575089213737087, 1.575089213737087, 2.02057521525713, 2.02057521525713, 2.02057521525713]
# 75
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.5202483898669343, 3.5202483898669343, 9.911233564636515, 3.6550503242351127, 3.6550503242351127, 2.4345178497627256, 2.4345178497627256, 2.4345178497627256]
# 76
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.9912764936465936, 1.9912764936465936, 11.598564904907388, 4.102156443180256, 4.102156443180256, 3.44963984608679, 3.44963984608679, 3.44963984608679]
# 77
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.84818622421721, 2.84818622421721, 10.79432454168919, 6.981711531869906, 6.981711531869906, 2.019405955484419, 2.019405955484419, 2.019405955484419]
# 78
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.348741609799611, 3.348741609799611, 9.504299194838016, 2.303645030409945, 2.303645030409945, 3.8339374281459726, 3.8339374281459726, 3.8339374281459726]
# 79
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.6506975627950664, 1.6506975627950664, 4.990018456497125, 6.199534008492277, 6.199534008492277, 1.36417468946963, 1.36417468946963, 1.36417468946963]
# 80
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.444283839208822, 3.444283839208822, 11.162120461741555, 1.9416553830527647, 1.9416553830527647, 3.8555629204893553, 3.8555629204893553, 3.8555629204893553]
# 81
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.2095140676281795, 3.2095140676281795, 10.43524912343869, 5.825150637183924, 5.825150637183924, 4.6277845542339655, 4.6277845542339655, 4.6277845542339655]
# 82
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.98282889674263, 5.98282889674263, 12.089447287007506, 4.703746454194164, 4.703746454194164, 1.2064356595929424, 1.2064356595929424, 1.2064356595929424]
# 83
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.141819209349091, 2.141819209349091, 7.403541123121944, 3.526689846372093, 3.526689846372093, 2.363623827970819, 2.363623827970819, 2.363623827970819]
# 84
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.41326723040039, 5.41326723040039, 8.118267045855834, 4.795167346270835, 4.795167346270835, 3.2229109407401153, 3.2229109407401153, 3.2229109407401153]
# 85
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.3601321727711433, 3.3601321727711433, 3.792933504230197, 3.55599454992866, 3.55599454992866, 2.084796414148686, 2.084796414148686, 2.084796414148686]
# 86
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.961171480703227, 4.961171480703227, 4.682266476216098, 5.092465618642678, 5.092465618642678, 3.32691407179581, 3.32691407179581, 3.32691407179581]
# 87
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.059807660131847, 4.059807660131847, 8.98791270348977, 5.735050024076522, 5.735050024076522, 1.8275972775562574, 1.8275972775562574, 1.8275972775562574]
# 88
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.493389547901853, 5.493389547901853, 9.761650500718694, 3.1078912567816923, 3.1078912567816923, 2.208865189990129, 2.208865189990129, 2.208865189990129]
# 89
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.3204052406232485, 5.3204052406232485, 10.750255332060643, 6.373297144251652, 6.373297144251652, 2.587801401484998, 2.587801401484998, 2.587801401484998]
# 90
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.6482579829402537, 3.6482579829402537, 5.6365261729076135, 3.611023980896169, 3.611023980896169, 3.8378099695740033, 3.8378099695740033, 3.8378099695740033]
# 91
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.6928143632299393, 3.6928143632299393, 8.196539391568239, 2.8038989855806253, 2.8038989855806253, 1.4095254332130005, 1.4095254332130005, 1.4095254332130005]
# 92
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [1.4117128450838485, 1.4117128450838485, 14.447349417363663, 2.080262999638405, 2.080262999638405, 1.7303852917588087, 1.7303852917588087, 1.7303852917588087]
# 93
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [3.3859927642963656, 3.3859927642963656, 11.299152530577715, 6.3103526860914485, 6.3103526860914485, 3.4982489700903354, 3.4982489700903354, 3.4982489700903354]
# 94
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [5.968926159944605, 5.968926159944605, 9.975681865698235, 2.69833308358177, 2.69833308358177, 2.4096974475660633, 2.4096974475660633, 2.4096974475660633]
# 95
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.706810854000485, 2.706810854000485, 13.814107423163733, 1.0278613850388436, 1.0278613850388436, 2.4709385268118256, 2.4709385268118256, 2.4709385268118256]
# 96
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.564058778444112, 2.564058778444112, 7.90646504517054, 2.4537617721541336, 2.4537617721541336, 1.0942054355403106, 1.0942054355403106, 1.0942054355403106]
# 97
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [4.082879411258438, 4.082879411258438, 13.837844222377269, 2.9990771144307327, 2.9990771144307327, 4.005298010282809, 4.005298010282809, 4.005298010282809]
# 98
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done
# ## Conversion done...
# ## Stars selected: 18658
# ## Normalization Normal-Gauss done on filtered data..
# [2.0267518210560054, 2.0267518210560054, 3.6461498298902675, 5.332127191529665, 5.332127191529665, 1.8725715110185384, 1.8725715110185384, 1.8725715110185384]
# 99
# # k-means done
# # Ward done
# # Spectral done
# # DBSCAN done

# %%
print("## k-means...")

# KMeans for each normalisation
kmeans = cluster.KMeans(n_clusters= kCluster, max_iter = 2000, n_init = 50)
kmeans.fit(source.dfnorm)
labels_k = kmeans.labels_
for i in range(kCluster):
    print("# Label %5d : %5d  Dist: %6.1f (%5.1f)"%(i,len(labels_k[np.where(labels_k == i)]), np.median(source.df[np.where(labels_k == i),2]), np.std(source.df[np.where(labels_k == i),2])))
print("##")

###########
print("## Ward... ")
# connectivity matrix for structured Ward

connectivity = kneighbors_graph(source.dfnorm, n_neighbors= neighbors, include_self=False)
# make connectivity symmetric
connectivity = 0.5 * (connectivity + connectivity.T)

ward = cluster.AgglomerativeClustering(n_clusters= kCluster, linkage='ward', connectivity=connectivity)
ward.fit(source.dfnorm)
labels_w = ward.labels_
for i in range(kCluster):
    print("# Label %5d : %5d  Dist: %6.1f (%5.1f)"%(i,len(labels_w[np.where(labels_w == i)]), np.median(source.df[np.where(labels_w == i),2]),np.std(source.df[np.where(labels_w == i),2])))
print("##")
    
############# 
print("## Spectral...")
spectral = cluster.SpectralClustering(n_clusters = kCluster, eigen_solver='arpack', affinity="nearest_neighbors")
spectral.fit(source.dfnorm)
labels_s = spectral.labels_
for i in range(kCluster):
    print("# Label %5d : %5d  Dist: %6.1f (%5.1f)"%(i,len(labels_s[np.where(labels_s == i)]), np.median(source.df[np.where(labels_s == i),2]),np.std(source.df[np.where(labels_s == i),2])))
print("##")


############# 
print("## DBSCAN...")
dbscan = cluster.DBSCAN(eps, min_samples)
dbscan.fit(source.dfnorm)
labels_d = spectral.labels_
for i in range(max(labels_d)+1):
    print("# Label %5d : %5d  Dist: %6.1f (%5.1f)"%(i,len(labels_d[np.where(labels_d == i)]), np.median(source.df[np.where(labels_d == i),2]), np.std(source.df[np.where(labels_d == i),2]) ))
print("##")
# Out:
# ## k-means...
# # Label     0 :  1828  Dist:  508.8 (227.9)
# # Label     1 :  1948  Dist:  573.3 (252.5)
# # Label     2 :  1646  Dist:  490.4 (224.4)
# # Label     3 :  2004  Dist: 1373.9 (280.3)
# # Label     4 :  1954  Dist:  552.3 (246.9)
# # Label     5 :  1716  Dist: 1298.5 (287.7)
# # Label     6 :  1933  Dist: 1320.0 (286.4)
# # Label     7 :  1734  Dist:  549.8 (248.0)
# # Label     8 :  2073  Dist: 1343.7 (287.7)
# # Label     9 :  1822  Dist:  637.9 (230.9)
# ##
# ## Ward...
# # Label     0 :  1953  Dist:  580.0 (214.9)
# # Label     1 :  3243  Dist:  668.8 (329.4)
# # Label     2 :  2208  Dist: 1150.9 (354.7)
# # Label     3 :  2087  Dist:  493.3 (258.0)
# # Label     4 :  2250  Dist:  433.8 (203.5)
# # Label     5 :  1819  Dist: 1156.1 (320.8)
# # Label     6 :  2305  Dist: 1377.0 (333.6)
# # Label     7 :   874  Dist: 1584.2 (240.5)
# # Label     8 :  1183  Dist:  835.7 (331.9)
# # Label     9 :   736  Dist: 1431.5 (272.3)
# ##
# ## Spectral...
# # Label     0 :  1288  Dist:  327.8 (137.4)
# # Label     1 :  1991  Dist:  451.0 (197.6)
# # Label     2 :  3495  Dist:  725.7 (258.4)
# # Label     3 :  1569  Dist: 1522.0 (241.4)
# # Label     4 :  2076  Dist: 1270.2 (321.5)
# # Label     5 :   132  Dist:  596.4 ( 38.1)
# # Label     6 :  2193  Dist:  470.4 (215.3)
# # Label     7 :  2288  Dist:  790.8 (297.2)
# # Label     8 :  1663  Dist: 1205.6 (323.0)
# # Label     9 :  1963  Dist: 1395.4 (285.8)
# ##
# ## DBSCAN...
# # Label     0 :  1288  Dist:  327.8 (137.4)
# # Label     1 :  1991  Dist:  451.0 (197.6)
# # Label     2 :  3495  Dist:  725.7 (258.4)
# # Label     3 :  1569  Dist: 1522.0 (241.4)
# # Label     4 :  2076  Dist: 1270.2 (321.5)
# # Label     5 :   132  Dist:  596.4 ( 38.1)
# # Label     6 :  2193  Dist:  470.4 (215.3)
# # Label     7 :  2288  Dist:  790.8 (297.2)
# # Label     8 :  1663  Dist: 1205.6 (323.0)
# # Label     9 :  1963  Dist: 1395.4 (285.8)
# ##

# %%
## Metrics of the solutions
np.random.seed(0)
labs = labels_k
qk = metric2(source.df, labs , APERTURE = 0.5 , MAXRADIUS = 0.9 * RADIUS, SIGCLIP = 0.0) 
labs = labels_w
qw = metric2(source.df, labs , APERTURE = 0.5 , MAXRADIUS = 0.9 * RADIUS, SIGCLIP = 0.0) 
labs = labels_s
qs = metric2(source.df, labs , APERTURE = 0.5 , MAXRADIUS = 0.9 * RADIUS, SIGCLIP = 0.0) 
labs = labels_d
qd = metric2(source.df, labs , APERTURE = 0.5 , MAXRADIUS = 0.9 * RADIUS, SIGCLIP = 0.0)  

plt.yscale("log", nonposy='clip')
plt.xlim([0,kCluster+1])
plt.errorbar(qk['label'],qk['Q'], qk['Q_err'], label='k-means',fmt='.k', ecolor='gray', lw=1, capsize=5)
plt.errorbar(qw['label'],qw['Q'], qw['Q_err'], label='Ward', fmt='*r', ecolor='gray', lw=1, capsize=5)
plt.errorbar(qs['label'],qs['Q'], qs['Q_err'], label='Spectral', fmt='Db', ecolor='gray', lw=1, capsize=5)
plt.errorbar(qd['label'],qd['Q'], qd['Q_err'], label='DBSCAN', fmt='og', ecolor='gray', lw=1, capsize=5)
plt.legend(loc='upper right', shadow=True)
plt.xlabel("Label")
plt.show()

# %%
## separation distance
angl2pc = 3600. * 150e6 * distclust / 3.1e13
print("## Angular distance (1deg) : %3.1 pc"%(angl2pc))
plot2d(source.df, labels_d,7, cmap = "hsv")
